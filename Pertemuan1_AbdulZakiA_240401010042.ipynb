# %%
# Pertemuan1 - Pengenalan Data Science
Nama = Abdul Zaki Al-Mutaqin
NIM = 240401010042
Kelas = IF403
## Tujuan Pratikum
Mempelajari konsep dasar Data Sience,peran Data Scientist, serta tahapan CRISP-DM yang digunakan dalam proyek Data Science.

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama = "Abdul Zaki"
angkatan = 2024
ipk = 3.75
aktif = True

print(f"Nama : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")

# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")

for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")

# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Abdul Zaki", "Informatika", 2024)

print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Abdul Zaki
# Angkatan : 2024
# IPK : 3.75
# Aktif : True
#
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub
# Hai! Saya Abdul Zaki dari Informatika, angkatan 2024.

# %% [markdown]
# # Kesimpulan
#
# Pada pertemuan pertama ini saya belajar tentang pengertian Data Science dan bagaimana data dapat digunakan untuk membantu pengambilan keputusan.
#
# Dari materi yang dipelajari, saya memahami bahwa Data Science bukan hanya tentang membuat program, tetapi juga tentang memahami data dan mengolahnya menjadi informasi yang bermanfaat. Materi ini menjadi dasar untuk mempelajari topik-topik berikutnya dalam mata kuliah Data Science.
